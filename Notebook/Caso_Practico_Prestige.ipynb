# %% [markdown]
# Librerias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Cargar dataset y mostrar primeras filas

# %%
df = pd.read_csv(
    'https://raw.githubusercontent.com/MendezBy02/Caso_Practico_Prestige/refs/heads/main/Archivos/Prestige_modificado.csv',
    sep=';'
)

print(df.head())
# Out:
#             occupation  education  income  women  prestige  census  type_num
# 0   gov.administrators      13.11   12351  11.16      68.8    1113         1
# 1     general.managers      12.26   25879   4.02      69.1    1130         1
# 2          accountants      12.77    9271  15.70      63.4    1171         1
# 3  purchasing.officers      11.42    8865   9.11      56.8    1175         1
# 4             chemists      14.62    8403  11.68      73.5    2111         1

# %% [markdown]
# Tamaño del dataset

# %%
print("Filas y columnas:")
print(df.shape)
# Out:
# Filas y columnas:
# (102, 7)

# %% [markdown]
# Información General

# %%
# Información general del dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   occupation  102 non-null    object
#  1   education   102 non-null    float64
#  2   income      102 non-null    int64
#  3   women       102 non-null    float64
#  4   prestige    102 non-null    float64
#  5   census      102 non-null    int64
#  6   type_num    102 non-null    int64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 5.7+ KB
# None

# %% [markdown]
# Nombres de columnas

# %%
print(df.columns)
# Out:
# Index(['occupation', 'education', 'income', 'women', 'prestige', 'census',
#        'type_num'],
#       dtype='object')

# %% [markdown]
# Buscando valores nulos

# %%
# Valores nulos
print(df.isnull().sum())
# Out:
# occupation    0
# education     0
# income        0
# women         0
# prestige      0
# census        0
# type_num      0
# dtype: int64

# %% [markdown]
# Buscando duplicados

# %%
# Registros duplicados
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# Estadisticas descriptivas

# %%
# Estadísticas generales
print(df.describe())
# Out:
#         education        income       women    prestige       census  \
# count  102.000000    102.000000  102.000000  102.000000   102.000000
# mean    10.738039   6797.901961   28.979020   46.833333  5401.774510
# std      2.728444   4245.922227   31.724931   17.204486  2644.993215
# min      6.380000    611.000000    0.000000   14.800000  1113.000000
# 25%      8.445000   4106.000000    3.592500   35.225000  3120.500000
# 50%     10.540000   5930.500000   13.600000   43.600000  5135.000000
# 75%     12.647500   8187.250000   52.202500   59.275000  8312.500000
# max     15.970000  25879.000000   97.510000   87.200000  9517.000000
#
#          type_num
# count  102.000000
# mean     1.843137
# std      0.817447
# min      0.000000
# 25%      1.000000
# 50%      2.000000
# 75%      2.000000
# max      3.000000

# %% [markdown]
# Tipos de datos

# %%
print(df.dtypes)
# Out:
# occupation     object
# education     float64
# income          int64
# women         float64
# prestige      float64
# census          int64
# type_num        int64
# dtype: object

# %% [markdown]
# # ===================================
# # ACTIVIDAD 2 - CORRELACIÓN
# # ===================================

# %%
# Seleccionar variables numéricas
variables_numericas = df.select_dtypes(include=['int64', 'float64'])

# Crear matriz de correlación
matriz_correlacion = variables_numericas.corr()

# Mostrar matriz
print(matriz_correlacion.round(3))
# Out:
#            education  income  women  prestige  census  type_num
# education      1.000   0.578  0.062     0.850  -0.823    -0.382
# income         0.578   1.000 -0.441     0.715  -0.361    -0.368
# women          0.062  -0.441  1.000    -0.118  -0.227     0.251
# prestige       0.850   0.715 -0.118     1.000  -0.635    -0.465
# census        -0.823  -0.361 -0.227    -0.635   1.000     0.288
# type_num      -0.382  -0.368  0.251    -0.465   0.288     1.000

# %%
# Correlación con Prestige
print(matriz_correlacion['prestige'].sort_values(ascending=False).round(3))
# Out:
# prestige     1.000
# education    0.850
# income       0.715
# women       -0.118
# type_num    -0.465
# census      -0.635
# Name: prestige, dtype: float64

# %% [markdown]
# # ===================================
# # ACTIVIDAD 3 - VISUALIZACIÓN DE DATOS
# # ===================================

# %%
import matplotlib.pyplot as plt

# Gráfico Education vs Prestige
plt.figure(figsize=(8,5))

plt.scatter(df['education'], df['prestige'])

plt.xlabel('Education')
plt.ylabel('Prestige')

plt.title('Relación entre Education y Prestige')

plt.grid(True)

plt.show()

# %%
# Gráfico Income vs Prestige
plt.figure(figsize=(8,5))

plt.scatter(df['income'], df['prestige'])

plt.xlabel('Income')
plt.ylabel('Prestige')

plt.title('Relación entre Income y Prestige')

plt.grid(True)

plt.show()

# %%
# Promedio de prestige por tipo de ocupación

df.groupby('type_num')['prestige'].mean().plot(
    kind='bar',
    figsize=(8,5)
)

plt.xlabel('Tipo de ocupación')
plt.ylabel('Promedio de Prestige')

plt.title('Prestige promedio por tipo de ocupación')

plt.grid(True)

plt.show()

# %% [markdown]
# # ===================================
# # ACTIVIDAD 4 - CLUSTERIZACIÓN
# # ===================================

# %% [markdown]
# Importando librerias para clusterización

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %% [markdown]
# Seleccionar columnas

# %%
# Variables para clusterización

columnas_cluster = [
    'education',
    'income',
    'women',
    'prestige',
    'type_num'
]

X = df[columnas_cluster].copy()

# %% [markdown]
# Escalar datos

# %%
# Escalamiento de datos

escalador = StandardScaler()

X_escalado = escalador.fit_transform(X)

# %% [markdown]
# Modelo con 4 clusters

# %%
# Modelo K-Means con 4 clusters

modelo_k4 = KMeans(
    n_clusters=4,
    random_state=42,
    n_init=10
)

df['Cluster_4'] = modelo_k4.fit_predict(X_escalado)

print(df.groupby('Cluster_4')[columnas_cluster].mean().round(2))
# Out:
#            education    income  women  prestige  type_num
# Cluster_4
# 0              13.59   7329.35  36.35     63.33      0.95
# 1               8.82   5878.74   9.60     37.26      2.09
# 2              10.12   3545.04  74.16     37.76      2.57
# 3              14.69  15746.83   6.00     74.23      1.00

# %% [markdown]
# Modelo con 5 clusters

# %%
# Modelo K-Means con 5 clusters

modelo_k5 = KMeans(
    n_clusters=5,
    random_state=42,
    n_init=10
)

df['Cluster_5'] = modelo_k5.fit_predict(X_escalado)

print(df.groupby('Cluster_5')[columnas_cluster].mean().round(2))
# Out:
#            education    income  women  prestige  type_num
# Cluster_5
# 0              10.94   3909.12  73.76     41.50      2.88
# 1               9.31   6922.03   5.84     42.18      2.25
# 2              13.59   7329.35  36.35     63.33      0.95
# 3               7.78   3327.48  34.10     26.87      1.71
# 4              14.69  15746.83   6.00     74.23      1.00
